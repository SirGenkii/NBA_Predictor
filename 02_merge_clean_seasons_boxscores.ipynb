# %% [markdown]
# # Notebook 1: Scraping des matchs et boxscores V3 depuis 2010

# %%
from datetime import datetime
from src.nba_scrapping import *
from src.utils import get_latest_file
from src.config import *
import pandas as pd

# %%
#store start time of notebook
start_time = datetime.now()
print("Start time: ", start_time)
# Out:
# Start time:  2025-06-04 19:06:45.361749

# %% [markdown]
# # TO REMOVE LATER (retry errors for 2012-13 only)

# %%
retry_seasons = ["2012-13"]

for retry_season in retry_seasons:
    print(f"--- Retry des boxscores échoués pour la saison {retry_season} ---")
    
    season_batch_dir = os.path.join(DATA_BOXSCORES_BATCHES_DIR, retry_season)
    
    retry_failed_boxscores_for_season(season_batch_dir)
# Out:
# --- Retry des boxscores échoués pour la saison 2012-13 ---
# [INFO] Retrying 18 GAME_IDs for season folder data\raw\boxscores\batches\2012-13
# [MOVE] data\raw\boxscores\batches\2012-13\traditional\errors_batch_17.txt to data\raw\boxscores\batches\2012-13\traditional\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\traditional\errors_batch_22.txt to data\raw\boxscores\batches\2012-13\traditional\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\traditional\errors_batch_23.txt to data\raw\boxscores\batches\2012-13\traditional\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\traditional\errors_batch_24.txt to data\raw\boxscores\batches\2012-13\traditional\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\traditional\errors_batch_7.txt to data\raw\boxscores\batches\2012-13\traditional\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\traditional\errors_batch_8.txt to data\raw\boxscores\batches\2012-13\traditional\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\advanced\errors_batch_17.txt to data\raw\boxscores\batches\2012-13\advanced\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\advanced\errors_batch_22.txt to data\raw\boxscores\batches\2012-13\advanced\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\advanced\errors_batch_23.txt to data\raw\boxscores\batches\2012-13\advanced\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\advanced\errors_batch_24.txt to data\raw\boxscores\batches\2012-13\advanced\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\advanced\errors_batch_7.txt to data\raw\boxscores\batches\2012-13\advanced\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\advanced\errors_batch_8.txt to data\raw\boxscores\batches\2012-13\advanced\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\fourfactors\errors_batch_17.txt to data\raw\boxscores\batches\2012-13\fourfactors\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\fourfactors\errors_batch_22.txt to data\raw\boxscores\batches\2012-13\fourfactors\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\fourfactors\errors_batch_23.txt to data\raw\boxscores\batches\2012-13\fourfactors\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\fourfactors\errors_batch_24.txt to data\raw\boxscores\batches\2012-13\fourfactors\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\fourfactors\errors_batch_7.txt to data\raw\boxscores\batches\2012-13\fourfactors\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\fourfactors\errors_batch_8.txt to data\raw\boxscores\batches\2012-13\fourfactors\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\misc\errors_batch_17.txt to data\raw\boxscores\batches\2012-13\misc\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\misc\errors_batch_22.txt to data\raw\boxscores\batches\2012-13\misc\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\misc\errors_batch_23.txt to data\raw\boxscores\batches\2012-13\misc\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\misc\errors_batch_24.txt to data\raw\boxscores\batches\2012-13\misc\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\misc\errors_batch_7.txt to data\raw\boxscores\batches\2012-13\misc\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\misc\errors_batch_8.txt to data\raw\boxscores\batches\2012-13\misc\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\scoring\errors_batch_17.txt to data\raw\boxscores\batches\2012-13\scoring\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\scoring\errors_batch_22.txt to data\raw\boxscores\batches\2012-13\scoring\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\scoring\errors_batch_23.txt to data\raw\boxscores\batches\2012-13\scoring\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\scoring\errors_batch_24.txt to data\raw\boxscores\batches\2012-13\scoring\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\scoring\errors_batch_7.txt to data\raw\boxscores\batches\2012-13\scoring\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\scoring\errors_batch_8.txt to data\raw\boxscores\batches\2012-13\scoring\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\usage\errors_batch_17.txt to data\raw\boxscores\batches\2012-13\usage\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\usage\errors_batch_22.txt to data\raw\boxscores\batches\2012-13\usage\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\usage\errors_batch_23.txt to data\raw\boxscores\batches\2012-13\usage\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\usage\errors_batch_24.txt to data\raw\boxscores\batches\2012-13\usage\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\usage\errors_batch_7.txt to data\raw\boxscores\batches\2012-13\usage\errors_processed
# [MOVE] data\raw\boxscores\batches\2012-13\usage\errors_batch_8.txt to data\raw\boxscores\batches\2012-13\usage\errors_processed
# [RETRY] GAME_ID 0021200161 (1/18)
# http://tklpflkn-137299:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-131171:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-101913:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-134641:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-114105:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-120266:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-104867:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200184 (2/18)
# http://tklpflkn-136103:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-135343:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-134111:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-133560:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-134283:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-127378:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200189 (3/18)
# http://tklpflkn-108967:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-116912:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-122801:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-142340:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-110440:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-109544:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200405 (4/18)
# http://tklpflkn-139376:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-142269:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-143876:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-117374:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-124285:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-131242:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200407 (5/18)
# http://tklpflkn-122726:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-101605:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-132918:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-100236:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-106687:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-111440:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200408 (6/18)
# http://tklpflkn-100867:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-145899:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-105772:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-131554:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-113118:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-130863:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200409 (7/18)
# http://tklpflkn-106495:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-107118:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-102439:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-115403:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-131516:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-107498:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200412 (8/18)
# http://tklpflkn-105876:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-109703:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-138523:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-110224:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-124188:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-135606:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-140267:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200530 (9/18)
# http://tklpflkn-136002:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-112436:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-109354:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-145935:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-111556:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-147640:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200536 (10/18)
# http://tklpflkn-119399:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-129665:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-139678:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-130450:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-108078:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-113998:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200544 (11/18)
# http://tklpflkn-114212:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-141530:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-136345:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-134707:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-131824:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-128650:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200564 (12/18)
# http://tklpflkn-122446:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-127365:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-123492:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-117429:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-129245:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-136917:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200566 (13/18)
# http://tklpflkn-110922:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-107428:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-108119:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-116040:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-106675:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-108933:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200575 (14/18)
# http://tklpflkn-141846:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-120768:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-141472:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-111361:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-106471:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-113060:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200581 (15/18)
# http://tklpflkn-101052:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-131381:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-123225:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-103908:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-130079:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-129176:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200583 (16/18)
# http://tklpflkn-124055:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-129494:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-148285:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-145331:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-137833:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-132298:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200595 (17/18)
# http://tklpflkn-116041:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-108561:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-103773:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-111483:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-104816:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-115945:ekjqv341wl4w@p.webshare.io:80
# [RETRY] GAME_ID 0021200600 (18/18)
# http://tklpflkn-129781:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-145438:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-126223:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-100588:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-115061:ekjqv341wl4w@p.webshare.io:80
# http://tklpflkn-141832:ekjqv341wl4w@p.webshare.io:80
# [SAVED] traditional retry batch 1 (457 rows)
# [SAVED] advanced retry batch 1 (457 rows)
# [SAVED] fourfactors retry batch 1 (457 rows)
# [SAVED] misc retry batch 1 (457 rows)
# [SAVED] scoring retry batch 1 (457 rows)
# [SAVED] usage retry batch 1 (457 rows)
# ✅ Retry process completed.

# %% [markdown]
# # Saisons ciblées

# %%
#seasons = [f"{y}-{str(y+1)[-2:]}" for y in range(2011, 2015)]
seasons = ["2011-12","2012-13"]
seasons
# Out:
# ['2011-12', '2012-13']

# %% [markdown]
# # Merge batches and remove duplicate for all endpoints

# %%
for season in seasons:
    print(f"--- Merging boxscores endpoints for {season} ---")
    
    season_batch_dir = os.path.join(DATA_BOXSCORES_BATCHES_DIR, season)
    
    merge_boxscore_batches_for_season(season_batch_dir)
# Out:
# --- Merging boxscores endpoints for 2011-12 ---
# [MERGED] traditional saved to data\raw\boxscores\batches\2011-12\merged_batches\merged_traditional.csv (27638 rows)
# [MERGED] advanced saved to data\raw\boxscores\batches\2011-12\merged_batches\merged_advanced.csv (27638 rows)
# [MERGED] fourfactors saved to data\raw\boxscores\batches\2011-12\merged_batches\merged_fourfactors.csv (27638 rows)
# [MERGED] misc saved to data\raw\boxscores\batches\2011-12\merged_batches\merged_misc.csv (27638 rows)
# [MERGED] scoring saved to data\raw\boxscores\batches\2011-12\merged_batches\merged_scoring.csv (27638 rows)
# [MERGED] usage saved to data\raw\boxscores\batches\2011-12\merged_batches\merged_usage.csv (27638 rows)
# --- Merging boxscores endpoints for 2012-13 ---
# [MERGED] traditional saved to data\raw\boxscores\batches\2012-13\merged_batches\merged_traditional.csv (33551 rows)
# [MERGED] advanced saved to data\raw\boxscores\batches\2012-13\merged_batches\merged_advanced.csv (33542 rows)
# [MERGED] fourfactors saved to data\raw\boxscores\batches\2012-13\merged_batches\merged_fourfactors.csv (33542 rows)
# [MERGED] misc saved to data\raw\boxscores\batches\2012-13\merged_batches\merged_misc.csv (33542 rows)
# [MERGED] scoring saved to data\raw\boxscores\batches\2012-13\merged_batches\merged_scoring.csv (33542 rows)
# [MERGED] usage saved to data\raw\boxscores\batches\2012-13\merged_batches\merged_usage.csv (33542 rows)

# %% [markdown]
# # Merge endpoints csv into one final with all columns

# %%
run_timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

for season in seasons:
    print(f"--- Merging all endpoints csv into final for {season} ---")
    
    season_merged_batch_dir = os.path.join(DATA_BOXSCORES_BATCHES_DIR, season, "merged_batches")
    
    all_boxscores_merged_filepath = merge_all_boxscore_stats(season_merged_batch_dir, output_filename=f"final_merged_all_boxscores_{run_timestamp}.csv")
    
    all_boxscores_merged_df = pd.read_csv(all_boxscores_merged_filepath, dtype={'gameId': str})
    
    #analyze_redundant_columns(all_boxscores_merged_df)
# Out:
# --- Merging all endpoints csv into final for 2011-12 ---
# Shape before cleaning: (27638, 164)
# [CLEAN] Renamed and dropped 55 redundant columns.
# [CLEAN] Dropped 9 highly correlated columns.
# Shape after cleaning: (27638, 100)
# ✅ All endpoints merged into: data\raw\boxscores\batches\2011-12\merged_batches\final_merged_all_boxscores_2025-06-04_19-15-01.csv (27638 rows)
# --- Merging all endpoints csv into final for 2012-13 ---
# Shape before cleaning: (33542, 164)
# [CLEAN] Renamed and dropped 55 redundant columns.
# [CLEAN] Dropped 9 highly correlated columns.
# Shape after cleaning: (33542, 100)
# ✅ All endpoints merged into: data\raw\boxscores\batches\2012-13\merged_batches\final_merged_all_boxscores_2025-06-04_19-15-01.csv (33542 rows)

# %% [markdown]
# # 🧩 Merge all seasons final boxscores into one

# %%
print("\n[MERGE] Concatenating all final_merged_all_boxscores_*.csv into one DataFrame")
final_files = []

for season in seasons:
    season_dir = os.path.join(DATA_BOXSCORES_BATCHES_DIR, season, "merged_batches")
    for file in os.listdir(season_dir):
        if file.startswith("final_merged_all_boxscores_") and file.endswith(".csv"):
            final_files.append(os.path.join(season_dir, file))

if not final_files:
    raise FileNotFoundError("❌ Aucun fichier final_merged_all_boxscores_*.csv trouvé.")

merged_df = pd.concat([pd.read_csv(f, dtype={'gameId': str}) for f in final_files], ignore_index=True)

os.makedirs(DATA_LAST_BOXSCORES_BATCHES_MERGED_DIR, exist_ok=True)
output_path = os.path.join(DATA_LAST_BOXSCORES_BATCHES_MERGED_DIR, f"all_seasons_boxscores_merged_{run_timestamp}.csv")
merged_df.to_csv(output_path, index=False)
print(f"✅ Sauvegardé dans : {output_path}")
# Out:
# [MERGE] Concatenating all final_merged_all_boxscores_*.csv into one DataFrame
# ✅ Sauvegardé dans : data\raw_last\batches_merged\all_seasons_boxscores_merged_2025-06-04_19-15-01.csv

# %% [markdown]
# # --- Merge games from each season (take most recent per season) ---

# %%
run_timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

all_games = []

#use custom format because of the way we store the games by periods or not for scrapping
season_dirs = [
    "2011-12_2011-12",
    "2012-13_2014-15",
    "2015-16_2019-20",
    "2020-21_2024-25"
]

for season_dir in season_dirs:
    season_games_dir = os.path.join(DATA_GAMES_DIR, season_dir)
    if os.path.exists(season_games_dir):
        game_files = [os.path.join(season_games_dir, f) for f in os.listdir(season_games_dir) if f.endswith('.csv')]
        if game_files:
            latest_file = max(game_files, key=os.path.getmtime)
            df_games = pd.read_csv(latest_file, dtype={'GAME_ID': str})
            all_games.append(df_games)

if all_games:
    all_games_df = pd.concat(all_games, ignore_index=True)
    games_output_path = os.path.join(DATA_LAST_GAMES_MERGED_DIR, f"games_merged_all_seasons_{run_timestamp}.csv")
    
    os.makedirs(DATA_LAST_GAMES_MERGED_DIR, exist_ok=True)
    
    all_games_df.to_csv(games_output_path, index=False)
    print(f"✅ Merged games saved to {games_output_path} ({len(all_games_df)} rows)")
# Out:
# ✅ Merged games saved to data\raw_last\games_merged\games_merged_all_seasons_2025-06-04_19-35-18.csv (35710 rows)

# %%
#store end time of notebook
end_time = datetime.now()
print("End time: ", end_time)
print("Total time: ", end_time - start_time)
# Out:
# End time:  2025-06-04 19:04:18.190071
# Total time:  0:00:31.478764

# %%
print("\n✅ Scraping historique V3 terminé")
# Out:
# ✅ Scraping historique V3 terminé

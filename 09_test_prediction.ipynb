# %%
import pandas as pd
from datetime import datetime
from src.config import *
from src.utils import *
from src.predictions import build_prediction_rows

pd.set_option("display.max_columns", None)

# ⏱️ Start
start_time = datetime.now()
print("Start time:", start_time)

# 🔁 Charger le dataset complet avec toutes les colonnes nécessaires
dataset_path = get_latest_file(DATA_FINAL_DATASET_DIR)
full_df = pd.read_csv(dataset_path)
full_df["GAME_DATE"] = pd.to_datetime(full_df["GAME_DATE"])
print("Loaded dataset:", dataset_path)


# 🧪 Extraction des deux dernières lignes (réelles)
real_last_rows = full_df.sort_values("GAME_DATE").tail(2).copy()
real_match_date = real_last_rows["GAME_DATE"].iloc[0]

home_id = real_last_rows.loc[real_last_rows["IS_HOME"] == 1, "TEAM_ID"].values[0]
away_id = real_last_rows.loc[real_last_rows["IS_HOME"] == 0, "TEAM_ID"].values[0]
home_odds = real_last_rows.loc[real_last_rows["IS_HOME"] == 1, "ODDS"].values[0]
away_odds = real_last_rows.loc[real_last_rows["IS_HOME"] == 0, "ODDS"].values[0]


print(f"Match: HOME={home_id}, AWAY={away_id}, Date={real_match_date.date()}")

# 🧼 Dataset sans ces lignes
#cut_df = full_df[full_df["GAME_DATE"] < real_match_date].copy()

#remove 2 last rows
cut_df = full_df.iloc[:-2].copy()
 
# display(cut_df.tail(6))
# display(full_df.tail(6))

# 🔁 Reconstruction des lignes à prédire
predicted_rows = build_prediction_rows(home_team_id=home_id, away_team_id=away_id, home_odds=home_odds,away_odds=away_odds, dataset=cut_df, match_date=real_match_date)

# 🧹 Préparation des lignes pour comparaison
#drop_cols = features_to_roll + COLS_MATCH_REAL + COLS_TO_DROP_TARGET_IS_WIN


real_clean = real_last_rows #.drop(columns=drop_cols, errors='ignore').reset_index(drop=True)
pred_clean = predicted_rows #.drop(columns=drop_cols, errors='ignore').reset_index(drop=True)

# 📏 Alignement des colonnes
common_cols = [col for col in real_clean.columns if col in pred_clean.columns]
real_clean = real_clean[common_cols]
pred_clean = pred_clean[common_cols]

# 🔍 Comparaison for floats and ints
diff = (pred_clean - real_clean).abs().sum()
diff_summary = diff[diff > 0.001].sort_values(ascending=False)
print(f"\nNombre de colonnes différentes : {len(diff_summary)}")
print("Colonnes divergentes :", diff_summary.index.tolist())

display(diff_summary)

print("\nLigne prédite:")
display(pred_clean)
print("\nLigne réelle:")
display(real_clean)

# 🕒 Fin
end_time = datetime.now()
print("End time:", end_time)
print("Duration:", end_time - start_time)
# Out:
# Start time: 2025-06-06 20:54:52.279881
# Loaded dataset: data\final_dataset\nba_features_final_2025-06-06_19-50-30.csv
# Match: HOME=1610612754, AWAY=1610612752, Date=2025-05-31
#
# Nombre de colonnes différentes : 0
# Colonnes divergentes : []
# Series([], dtype: float64)
# Ligne prédite:
#        IS_HOME  ROLL_fieldGoalsMade_traditional_3  \
# 38079      0.0                          81.928151
# 38080      1.0                          72.227196
#
#        ROLL_fieldGoalsMade_traditional_5  ROLL_fieldGoalsMade_traditional_10  \
# 38079                          80.661691                           79.676252
# 38080                          76.553805                           81.018311
#
#        ROLL_fieldGoalsMade_traditional_25  ROLL_fieldGoalsMade_traditional_50  \
# 38079                           80.190354                           81.982419
# 38080                           84.618293                           86.167588
#
#        ROLL_fieldGoalsMade_traditional_100  \
# ...

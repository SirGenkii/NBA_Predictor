# %% [markdown]
# # 40 · Train Debug
#
# **Contexte run**
# - `mlflow_experiment` : `<nom>`
# - `dataset_path` : `<parquet>`
# - `cutoff_date` : `<YYYY-MM-DD>`
#
# Checklist :
# - [ ] Distribution train/val/test cohérente
# - [ ] Features diff home/away correctement construites
# - [ ] Logs MLflow (metrics, params, artefacts) présents

# %%
import polars as pl
from pathlib import Path

DATASET_PATH = Path("data/gold/training_sets/latest.parquet")
dataset = pl.read_parquet(DATASET_PATH)
dataset.head()

# %%
dataset.describe()

# %% [markdown]
# ## Notes
# - Ajouter ici les validations supplémentaires (corrélation, drift)
# - Lancer ensuite `train_model_flow` pour un run complet

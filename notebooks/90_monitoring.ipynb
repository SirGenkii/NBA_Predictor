# %% [markdown]
# # 90 · Monitoring
#
# **Contexte run**
# - `period` : `<ex: 2024-03-01 → 2024-03-15>`
# - `model_version` : `<MLflow>`
# - `features_version` : `<team+H2H_v1>`
#
# Checklist :
# - [ ] Drift features vs training
# - [ ] Performance modèle (logloss, calibration)
# - [ ] Anomalies de production (latence, taux d’erreur)

# %%
import pandas as pd
from pathlib import Path

SCORING_PATH = Path('data/gold/scoring_payloads/latest.csv')
scoring_df = pd.read_csv(SCORING_PATH)
scoring_df.head()

# %% [markdown]
# ## Notes
# - Prévoir l’intégration avec un outil type Evidently
# - Ajouter des visualisations selon les besoins
